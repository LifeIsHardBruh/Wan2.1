# %%
import torch

# %%
data = torch.load("mask_step010.pt", map_location="cpu")
print(type(data))
# print(data if isinstance(data, (list, dict)) else str(data)[:500])
print(data.shape)
# Out:
# <class 'torch.Tensor'>
# torch.Size([21, 90, 160])
